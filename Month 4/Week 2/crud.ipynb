# %%
import chromadb

# %%
client=chromadb.PersistentClient(path="./chroma_db")
collection=client.get_collection(name="my_notes")

# %%
print(collection.count())
# Out:
# 4

# %%
collection.update(
    ids=["note1"],
    documents=["I need to buy groceries: milk, eggs, bread, and PIZZA."]
)

# %%
collection.delete(ids=["note4"])

# %%
collection.count()
# Out:
# 3

# %%
results=collection.query(
    query_texts=["pizza"],
    n_results=1
)

# %%
results
# Out:
# {'ids': [['note1']],
#  'embeddings': None,
#  'documents': [['I need to buy groceries: milk, eggs, bread, and PIZZA.']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[1.1252315044403076]]}

# %%
collection.get()
# Out:
# {'ids': ['note1', 'note2', 'note3'],
#  'embeddings': None,
#  'documents': ['I need to buy groceries: milk, eggs, bread, and PIZZA.',
#   'The project deadline is next Friday.',
#   'To fix the bug, restart the server and clear cache.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None, None]}
